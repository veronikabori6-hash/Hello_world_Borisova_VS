# %%
# task_2-2_1.py

course_name  = "биотехнические системы"
Current_Stage_Number = 1
Number_of_completed_tasks = 2.1
print(f"Название курса: {course_name}, Номер текущего этапа: {Current_Stage_Number}, Количество выполненных задач: {Number_of_completed_tasks}")
# Out:
# Название курса: биотехнические системы, Номер текущего этапа: 1, Количество выполненных задач: 2.1
