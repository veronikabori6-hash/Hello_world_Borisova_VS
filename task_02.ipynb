# %%
# task_2-0_1.py
# Первая программа: вывод текста
print ('Hello World!')
# Out:
# Hello World!

# %%
# task_2-0_2.py
# Вывод информации о себе
print("Имя:","Вероника","Возраст:", 18)
print("Группа:","best_group","Год:", 2026)
# Out:
# Имя: Вероника Возраст: 18
# Группа: best_group Год: 2026

# %%
# task_2-0_3.py
# Вывод даты с разделителем "."
day = 4
month = 2
year = 2026

print(f"{day:02d}.{month:02d}.{year}")
# Out:
# 04.02.2026

# %%
# task_2-0_4.py
# Таблица с использованием табуляции

print("Предмет\t\tОценка")
print("Математика\t5")
print("Физика\t\t4")
print("Информатика\t5")
# Out:
# Предмет		Оценка
# Математика	5
# Физика		4
# Информатика	5

# %%
# task_2-0_5.py
# Использование переменных и f-строки

name = "Вероника"
group = "4731204/5003"
score = "5 из 5"

print(f"Студент {name} из группы {group} получил {score} баллов.")
# Out:
# Студент Вероника из группы 4731204/5003 получил 5 из 5 баллов.

# %%
# task_2-0_6.py
# Перенаправление вывода в файл

# Укажи свой полный путь к папке, например:
# "C:/Users/Вероника/Documents/ivanov_ie/projects_2/task_2_0/output.txt"

file_path = "output.txt"  # или укажи полный путь

with open(file_path, "w", encoding="utf-8") as file:
    print("Фамилия: Вероникина", file=file)
    print("Имя: Вероника", file=file)
    print("Группа: 4731204/5003", file=file)
    print("Год поступления: 2026", file=file)

print("Файл успешно создан!")
# Out:
# Файл успешно создан!

# %%
# task_2-0_creative.py
# Творческое задание: красивое оформление вывода

name = "Вероника"
year = 2026
group = "4731204/5003"

print("\n" + "=" * 40)
print("🌟 Приветствие пользователю 🌟".center(40))
print("=" * 40)

print(f"Добро пожаловать, {name}!", end="\n\n")
print(f"Ты учишься в группе {group}.", end=" ")
print(f"Текущий год обучения: {year}.\n")

print("-" * 40)
print("Успехов в учёбе! 🚀".center(40))
print("=" * 40 + "\n")
# Out:
# ...
#       🌟 ПРИВЕТСТВИЕ ПОЛЬЗОВАТЕЛЮ 🌟
# ...
# Добро пожаловать, Вероника!
#
# Ты учишься в группе 4731204/5003. Текущий год обучения: 2026.
#
# ----------------------------------------
#            Успехов в учёбе! 🚀
# ...
