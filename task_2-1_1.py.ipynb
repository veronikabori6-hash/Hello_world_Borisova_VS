# %%
# task_2-1_2.py

# Создаем переменную python_version со значением "3.10"
python_version = "3.10"

# Выводим строку: Language: Python
print("Language: Python")

# Выводим вторую строку с отступом (табуляцией): Version: 3.10
# Используем f-строку и символ табуляции \t
print(f"\tVersion: {python_version}")
# Out:
# Language: Python
# 	Version: 3.10

# %%
# task_2-1_1.py

# Запрашиваем имя пользователя
name = input("Введите имя: ")

# Запрашиваем возраст пользователя
age = input("Возраст: ")

# Выводим информацию о студенте
print("Студент:", name, sep=" : ", end="!\n")
# Out:
# Введите имя:  вероника
# Возраст:  18
# Студент: : вероника!
