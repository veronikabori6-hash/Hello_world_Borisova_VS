# %%
device_name = "Микроскоп"
inventory_number = "INV-2023-001"
is_operational = True
quantity = 8
print("Название прибора\tИнвентарный номер\tСостояние\tКоличество")
print(f"{device_name}\t\t{inventory_number}\t\t{'Исправен' if is_operational else 'Неисправен'}\t{quantity}")
# Out:
# Название прибора	Инвентарный номер	Состояние	Количество
# Микроскоп		INV-2023-001		Исправен	8
